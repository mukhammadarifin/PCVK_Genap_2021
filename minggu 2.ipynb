# %% [markdown]
# <a href="https://colab.research.google.com/github/mukhammadarifin/PCVK_Genap_2021/blob/main/minggu%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang
# sudah ada. Contohnya pada kode program di bawah file image dengan nama
# kitten01.jpg akan dibuka untuk diproses lebih lanjut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/image/kuciang oren.jpg')
plt.imshow(img)

# %% [markdown]
# OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)   #Konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# # TUGAS
#
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
#
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?

# %%
imgt1 = cv.cvtColor(img, cv.COLOR_BGR2RGB)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(imgt1)

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
imgt2a = cv.cvtColor(img, cv.COLOR_BGR2RGB)


imgt2a[:,:,0] = np.zeros([imgt2a.shape[0], imgt2a.shape[1]])
plt.imshow(imgt2a)

# %%
imgt2b = cv.cvtColor(img, cv.COLOR_BGR2RGB)


imgt2b[:,:,2] = np.zeros([imgt2b.shape[0], imgt2b.shape[1]])
plt.imshow(imgt2b)

# %% [markdown]
# 3. Tampilkan image baris ke 10-100, kolom 10-100!

# %%
imgt2b = imgt2b[10:100, 10:100]
plt.imshow(imgt2b)

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
plt.imshow(imgt2b[5:30])

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %%
imgt5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(imgt5, pt1=(384,0), pt2=(100,200), color=(0,255,0), thickness=10)
cv.rectangle(imgt5, pt1=(400,200), pt2=(510,150), color=(0,255,0), thickness=10)
cv.rectangle(imgt5, pt1=(200,500), pt2=(150,510), color=(0,255,0), thickness=10)
cv.rectangle(imgt5, pt1=(700,700), pt2=(800,150), color=(0,255,0), thickness=10)
cv.rectangle(imgt5, pt1=(700,700), pt2=(600,600), color=(0,255,0), thickness=10)

plt.imshow(imgt5)

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
imgt6 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(imgt6)

# %% [markdown]
# Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan
# citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/image/kuciang oren.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image
# dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
#Perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2
# yang tertulis pada kode program.

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,225), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
# tertulis pada kode program.

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-2)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan.

# %%
font = cv.FONT_HERSHEY_COMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200,400]], dtype= np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1, 1, 2))  #nilai untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengan memilih
# File kemudian “Save a copy in GitHub”.

# %% [markdown]
# # TUGAS
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 1. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
imgt = cv.imread('/content/drive/MyDrive/image/54782878.jpg')
plt.imshow(imgt)

# %%
imgt1b1 = cv.cvtColor(imgt, cv.COLOR_BGR2RGB)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(imgt1b1)

# %%
cv.rectangle(imgt1b1,pt1=(120,110),pt2=(245,250),color=(0,0,255), thickness=7)
plt.imshow(imgt1b1)

cv.circle(imgt1b1,center=(190,180),radius=65,color=(255,0,0),thickness=5)
plt.imshow(imgt1b1)

# %% [markdown]
# 2. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
cv.rectangle(imgt1b1,(5,330),(120,380),color=(0,0,255),thickness=5)
plt.imshow(imgt1b1)

# %% [markdown]
# 3. Tulis nama file pada file citra dari soal no.2. Gunakan font, ukuran font, dan
# warna font yang sesuai keinginan anda.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(imgt1b1, text='me',org=(10,60),fontFace=font,fontScale=3,color=(0,0,255),thickness=6,lineType=cv.LINE_4)
plt.imshow(imgt1b1)

# %% [markdown]
# Tunjukkan code program anda pada bapak/ibu dosen

# %% [markdown]
# # Pertanyaan
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#   Jawab :
#
#   perbedaanya adalah saat menggunakan matplotlib kita sudah ditampilkan gambar kita yang sudah ada dengan ukuran panjang dan lebar dari gambar tersebut.

# %% [markdown]
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
#   Jawab :
#
#   perbedaannya ada pada pengaruh size gambar, yang dimana int16 memiliki kapasitas file lebih sedikit dari pada int32

# %% [markdown]
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
#   Jawab :
#
#   untuk menampilkan gambar pada google collab menggunakan pacthes

# %% [markdown]
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
#   Jawab :
#
#   untuk melakukan load, read dan write gambar
